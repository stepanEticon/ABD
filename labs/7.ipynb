# %% [markdown]
# <a href="https://colab.research.google.com/github/Appendme/big_data_analysis/blob/master/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt, numpy as np, pandas as pd

# %%
df = pd.read_csv('samples/stores-dist.csv')
df.head()
# Out:
#    district  annual net sales  number of stores in district
# 0         1             231.0                            12
# 1         2             156.0                            13
# 2         3              10.0                            16
# 3         4             519.0                             2
# 4         5             437.0                             6

# %%
df.corr()
# Out:
#                               district  ...  number of stores in district
# district                      1.000000  ...                     -0.230617
# annual net sales              0.136103  ...                     -0.912236
# number of stores in district -0.230617  ...                      1.000000
#
# [3 rows x 3 columns]

# %%
df.rename(columns = {'annual net sales':'sales','number of stores in district':'stores'}, inplace = True)
df.drop('district', axis = 1, inplace = True)
df.head()
# Out:
#    sales  stores
# 0  231.0      12
# 1  156.0      13
# 2   10.0      16
# 3  519.0       2
# 4  437.0       6

# %%
x = df.stores
y = df.sales

# %matplotlib inline

plt.figure(figsize=(20,10))
plt.plot(x, y, 'o', markersize = 15)

plt.ylabel('Annual Net Sales', fontsize = 30)
plt.xlabel('Number of Stores in the District', fontsize = 30)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

plt.show()

# %%
m, b = np.polyfit(x, y, 1) 
print (f'The slope of line is {m:.2f}.')
print (f'The y-intercept is {b:.2f}.')
print (f'The best fit simple linear regression line is {m:.2f}x + {b:.2f}.')
# Out:
# The slope of line is -35.79.
# The y-intercept is 599.38.
# The best fit simple linear regression line is -35.79x + 599.38.

# %%
x_mean = x.mean()
y_mean = y.mean()    
print (f'The centroid for this dataset is x = {x_mean:.2f} and y = {y_mean:.2f}.')
# Out:
# The centroid for this dataset is x = 8.74 and y = 286.57.

# %%
# %matplotlib inline

plt.figure(figsize=(20,10))

# Plot the scatter plot of the data set
plt.plot(x, y, 'o', markersize = 14, label = "Annual Net Sales") 

# Plot the centroid point
plt.plot(x_mean, y_mean, '*', markersize = 30, color = "r") 

# Plot the linear regression line
plt.plot(x, m * x + b, '-', label = 'Simple Linear Regression Line', linewidth = 4)

plt.ylabel('Annual Net Sales', fontsize = 30)
plt.xlabel('Number of Stores in District', fontsize = 30)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.annotate('Centroid', xy=(x_mean-0.1, y_mean-5), xytext=(x_mean-3, y_mean-20), arrowprops=dict(facecolor='black', shrink=0.05), fontsize = 30)
plt.legend(loc = 'upper right', fontsize = 20)

# %%
def predict(query):
    if query >= 1:
        predict = m * query + b
        return predict
    else:
        print ("You must have at least 1 store in the district to predict the annual net sales.")

predict(27)
# Out:
# -366.8715975276367

# %%
predict(4)
# Out:
# 456.2313681207654

# %%
print("Выполнил: Коновалов С.В.")
